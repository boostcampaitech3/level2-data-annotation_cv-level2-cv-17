# %%
# %matplotlib inline
import glob
import json
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pathlib import Path
from PIL import Image
from collections import Counter
import numpy as np
from PIL import Image, ImageDraw, ImageFont

# %%
def read_json(filename):
    with Path(filename).open(encoding='utf8') as handle:
        ann = json.load(handle)
    return ann

# %%
data = read_json("../input/data/ICDAR17_Korean/ufo/train.json")

# %%
a = [[0,0],[0,1]]
list(map(lambda x: tuple(x),a))
# Out:
# [(0, 0), (0, 1)]

# %%
for image in data['images']:
    image = data['images'][image]
    img_h = image['img_h']
    img_w = image['img_w']
    for polygon in image['words']:
        for points in image['words'][polygon]['points']:
            points[0] = points[0]/img_w
            points[1] = points[1]/img_h
        image['words'][polygon]['points'] = list(map(lambda x: tuple(x),image['words'][polygon]['points']))

# %%
for image in data['images']:
    image = data['images'][image]
    img_h = image['img_h']
    img_w = image['img_w']
    for polygon in image['words']:
        for points in image['words'][polygon]['points']:
            points[0] = points[0]/img_w
            points[1] = points[1]/img_h
        image['words'][polygon]['points'] = list(map(lambda x: tuple(x),image['words'][polygon]['points']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/ml/code/utils.ipynb Cell 6' in <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2B118.67.129.236/opt/ml/code/utils.ipynb#ch0000003vscode-remote?line=4'>5</a> for polygon in image['words']:
#       <a href='vscode-notebook-cell://ssh-remote%2B118.67.129.236/opt/ml/code/utils.ipynb#ch0000003vscode-remote?line=5'>6</a>     for points in image['words'][polygon]['points']:
# ----> <a href='vscode-notebook-cell://ssh-remote%2B118.67.129.236/opt/ml/code/utils.ipynb#ch0000003vscode-remote?line=6'>7</a>         points[0] = points[0]/img_w
#       <a href='vscode-notebook-cell://ssh-remote%2B118.67.129.236/opt/ml/code/utils.ipynb#ch0000003vscode-remote?line=7'>8</a>         points[1] = points[1]/img_h
# ...

# %%
data
# Out:
# {'images': {'img_4380.jpg': {'img_h': 2448,
#    'img_w': 1836,
#    'words': {'0': {'points': [(0.36056644880174293, 0.30514705882352944),
#       (0.5147058823529411, 0.31004901960784315),
#       (0.5021786492374728, 0.6462418300653595),
#       (0.36655773420479304, 0.639297385620915)],
#      'transcription': '출입금지',
#      'language': ['ko'],
#      'illegibility': False,
#      'orientation': 'Horizontal',
#      'word_tags': None},
#     '1': {'points': [(0.25925925925925924, 0.22508169934640523),
#       (0.616557734204793, 0.22630718954248366),
#       (0.6089324618736384, 0.30514705882352944),
#       (0.2565359477124183, 0.29248366013071897)],
#      'transcription': '오토바이',
#      'language': ['ko'],
#      'illegibility': False,
#      'orientation': 'Horizontal',
#      'word_tags': None},
#     '2': {'points': [(0.24782135076252723, 0.11968954248366014),
#       (0.6230936819172114, 0.12663398692810457),
#       (0.6149237472766884, 0.21160130718954248),
# ...

# %%
with open('/opt/ml/input/data/ICDAR17_Korean/ufo/train_div.json','w') as f:
    json.dump(data,f)

# %%
k = data.copy()

# %%
data['images'].keys()
# Out:
# dict_keys(['img_4380.jpg', 'img_4583.jpg', 'img_4234.jpg', 'img_4345.jpg', 'img_4016.jpg', 'img_4273.jpg', 'img_4609.jpg', 'img_4072.jpg', 'img_4366.jpg', 'img_4712.jpg', 'img_4249.jpg', 'img_4290.jpg', 'img_4508.jpg', 'img_4322.jpg', 'img_4465.jpg', 'img_4389.jpg', 'img_4694.jpg', 'img_4384.jpg', 'img_4724.jpg', 'img_4728.jpg', 'img_4782.jpg', 'img_4570.jpg', 'img_4413.jpg', 'img_4251.jpg', 'img_4443.jpg', 'img_4705.jpg', 'img_4084.jpg', 'img_4769.jpg', 'img_4556.jpg', 'img_4615.jpg', 'img_4129.jpg', 'img_4279.jpg', 'img_4500.jpg', 'img_4127.jpg', 'img_4520.jpg', 'img_4199.jpg', 'img_4243.jpg', 'img_4104.jpg', 'img_4758.jpg', 'img_4415.jpg', 'img_4721.jpg', 'img_4289.jpg', 'img_4732.jpg', 'img_4139.jpg', 'img_4155.jpg', 'img_4607.jpg', 'img_4085.jpg', 'img_4632.jpg', 'img_4235.jpg', 'img_4094.jpg', 'img_4617.jpg', 'img_4331.jpg', 'img_4416.jpg', 'img_4073.jpg', 'img_4352.jpg', 'img_4463.jpg', 'img_4267.jpg', 'img_4738.jpg', 'img_4795.jpg', 'img_4437.jpg', 'img_4603.jpg', 'img_4767.j
# ...

# %%
# 샘플 한개 뽑아서, width heght로 나누고 그거에 맞게 points를 움직여주면 되는 듯

# %%
data
# Out:
# {'images': {'img_4380.jpg': {'img_h': 2448,
#    'img_w': 1836,
#    'words': {'0': {'points': [[662.0, 747.0],
#       [945.0, 759.0],
#       [922.0, 1582.0],
#       [673.0, 1565.0]],
#      'transcription': '출입금지',
#      'language': ['ko'],
#      'illegibility': False,
#      'orientation': 'Horizontal',
#      'word_tags': None},
#     '1': {'points': [[476.0, 551.0],
#       [1132.0, 554.0],
#       [1118.0, 747.0],
#       [471.0, 716.0]],
#      'transcription': '오토바이',
#      'language': ['ko'],
#      'illegibility': False,
#      'orientation': 'Horizontal',
#      'word_tags': None},
#     '2': {'points': [[455.0, 293.0],
#       [1144.0, 310.0],
#       [1129.0, 518.0],
#       [457.0, 496.0]],
#      'transcription': '자전거',
#      'language': ['ko'],
#      'illegibility': False,
#      'orientation': 'Horizontal',
#      'word_tags': None}},
#    'tags': None,
#    'license_tag': {'usability': True,
#     'public': True,
#     'commercial': True,
# ...

# %%
# tags, words가 tag들 핵심일 듯.
data['images']['img_4380.jpg']['words']['0'].keys()
# Out:
# dict_keys(['points', 'transcription', 'language', 'illegibility', 'orientation', 'word_tags'])

# %%
scale = 5 # 이미지 scale 조절, 나누는 값 1 or 5
def scaling(p): # scale에 맞춰 좌표값 조절, list(map(scaling, points))
    return (p[0]/scale, p[1]/scale)

# %%
fontsize = 20 * (5//scale)
fnt = ImageFont.truetype("NanumSquareR.ttf", fontsize, encoding="UTF-8")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/ml/code/utils.ipynb Cell 7' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B118.67.129.236/opt/ml/code/utils.ipynb#ch0000006vscode-remote?line=0'>1</a> fontsize = 20 * (5//scale)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B118.67.129.236/opt/ml/code/utils.ipynb#ch0000006vscode-remote?line=1'>2</a> fnt = ImageFont.truetype("NanumSquareR.ttf", fontsize, encoding="UTF-8")
#
# File /opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageFont.py:844, in truetype(font, size, index, encoding, layout_engine)
#     <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageFont.py?line=840'>841</a>     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageFont.py?line=842'>843</a> try:
# ...

# %%
cnt = 0
for img_name in sorted(data['images']):
    print(img_name)
    img = Image.open("../input/data/ICDAR17_Korean/images/" + img_name)
    w, h = data['images'][img_name]['img_w']//scale, data['images'][img_name]['img_h']//scale
    # w, h = img.width//scale, img.height//scale
    resize_img = img.resize((w, h))
    draw = ImageDraw.Draw(resize_img)
    # 단어 표시
    words = data['images'][img_name]['words']
    for word in words:
        points = list(map(scaling, words[word]['points']))
        draw.line(points+[points[0]], fill="red", width=2*(5//scale))
        text = words[word]['transcription']
        tw, th = fnt.getsize(text)
        draw.text((points[0][0], points[0][1]-th), text, font=fnt, fill="red")
    resize_img.show()
    if cnt == 3:
        break
    cnt += 1
# Out:
# img_1001.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageDraw.py:428, in ImageDraw.text.<locals>.draw_text(ink, stroke_width, stroke_offset)
#     <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageDraw.py?line=426'>427</a> try:
# --> <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageDraw.py?line=427'>428</a>     mask, offset = font.getmask2(
#     <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageDraw.py?line=428'>429</a>         text,
#     <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageDraw.py?line=429'>430</a>         mode,
#     <a href='file:///opt/conda/envs/hyo/lib/python3.10/site-packages/PIL/ImageDraw.py?line=430'>431</a>         direction=direction,
# ...
